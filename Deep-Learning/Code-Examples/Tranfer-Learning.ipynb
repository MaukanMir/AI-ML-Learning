# %%
PATH="/Users/maukanmir/Documents/MLE-Interview-Prep/MLE-Interview/images/fine-tune-learning-process.png"

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread(PATH)
plt.figure(figsize=(15, 8))
plt.imshow(img)
plt.axis('off')  
plt.show()
